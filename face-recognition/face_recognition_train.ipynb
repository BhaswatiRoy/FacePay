# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from imutils import paths
import numpy as np
import argparse
import imutils
import pickle
import cv2
import os

# %%
protoPath = "/content/deploy.prototxt"
modelPath = "res10_300x300_ssd_iter_140000.caffemodel"

detector = cv2.dnn.readNet(protoPath, modelPath)

# %%
import subprocess

command = 'python -m tf2onnx.convert --opset 11 --input input:0,cont:0 --inputs-as-nchw input:0 --output output:0 --fold_const --saved-model model_dir --verbose nn4.small2.v1.t7.pb'

x=subprocess.call(command.split(), shell=True)

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import torch

# %%
embedder = cv2.dnn.readNetFromTorch("/content/openface.nn4.small2.v1.t7")

# %%
imagePaths = []
main_dir = 'drive/MyDrive/Faceit/Image Dataset'
main_dir_list = os.listdir(main_dir)
for name in main_dir_list:
    name_dir = os.path.sep.join([main_dir, name])
    name_dir_list = os.listdir(name_dir)
    for image in name_dir_list:
        imagePath = os.path.sep.join([main_dir, name, image])
        imagePaths.append(imagePath)

# %%
for i in imagePaths:
    print(i.split(os.path.sep)[-2], " : ",i)
    print()
# Out:
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.9 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.8 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.2 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.7 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.6 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.5 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.14 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.15 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.16 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.3 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.4 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.13 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.12 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.11 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.10 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.7.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.9.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.8.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.5.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.6.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.1 (1).jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.4.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.2.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.3.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.14.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.10.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.15.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.16.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.11.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.12.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.13.jpg
#
# Tandrima  :  drive/MyDrive/Faceit/Image Dataset/Tandrima/1.1.jpg

# %%
# initialize our lists of extracted facial embeddings and corresponding people names
knownEmbeddings = []
knownNames = []
# initialize the total number of faces processed
total = 0
i = 0

# %%
import os

# %%
import cv2

# %%
for i in range(len(imagePaths)):
    
    imagePath = imagePaths[i]
    # extract the person name from the image path
    print("[INFO] processing image {}/{}".format(i + 1, len(imagePaths)))
    name = imagePath.split(os.path.sep)[-2]
    
    # load the image, resize it to have a width of 600 pixels (while maintaining the aspect ratio), and then grab the image
    # dimensions
    
    image = cv2.imread(imagePath)
 
    if image is None:
        continue
    (h, w) = image.shape[:2]

    
    # construct a blob from the image
    
    imageBlob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0, (300, 300),(104.0, 177.0, 123.0),
                                      swapRB=False, crop=False)
    
    # apply OpenCV's deep learning-based face detector to localize faces in the input image
    
    detector.setInput(imageBlob)
    detections = detector.forward()
    
    if len(detections) > 0:
        
        # we're making the assumption that each image has only ONE face, so find the bounding box with the largest probability
        
        i = np.argmax(detections[0, 0, :, 2])
        confidence = detections[0, 0, i, 2]
        
        # ensure that the detection with the largest probability also
        # means our minimum probability test (thus helping filter out
        # weak detections)
        
        if confidence > 0.5:
        
            # compute the (x, y)-coordinates of the bounding box for the face
        
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            
            # extract the face ROI and grab the ROI dimensions
            
            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]
            
            # ensure the face width and height are sufficiently large
            
            if fW < 20 or fH < 20:
                continue
            
            # construct a blob for the face ROI, then pass the blob through our face embedding model to obtain the 128-d
            # quantification of the face
            
            faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255, (96, 96), (0, 0, 0), swapRB=True, crop=False)
            embedder.setInput(faceBlob)
            vec = embedder.forward()
            
            # add the name of the person + corresponding face
            # embedding to their respective lists
            
            knownNames.append(name)
            knownEmbeddings.append(vec.flatten())
            total += 1
# Out:
# [INFO] processing image 1/32
# [INFO] processing image 2/32
# [INFO] processing image 3/32
# [INFO] processing image 4/32
# [INFO] processing image 5/32
# [INFO] processing image 6/32
# [INFO] processing image 7/32
# [INFO] processing image 8/32
# [INFO] processing image 9/32
# [INFO] processing image 10/32
# [INFO] processing image 11/32
# [INFO] processing image 12/32
# [INFO] processing image 13/32
# [INFO] processing image 14/32
# [INFO] processing image 15/32
# [INFO] processing image 16/32
# [INFO] processing image 17/32
# [INFO] processing image 18/32
# [INFO] processing image 19/32
# [INFO] processing image 20/32
# [INFO] processing image 21/32
# [INFO] processing image 22/32
# [INFO] processing image 23/32
# [INFO] processing image 24/32
# [INFO] processing image 25/32
# [INFO] processing image 26/32
# [INFO] processing image 27/32
# [INFO] processing image 28/32
# [INFO] processing image 29/32
# [INFO] processing image 30/32
# [INFO] processing image 31/32
# [INFO] processing image 32/32

# %%
data = {"embeddings": knownEmbeddings, "names": knownNames}
f = open('Trined_Embeddings', "wb")
f.write(pickle.dumps(data))
f.close()

# %%
from keras.layers import Dropout
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import pickle
from sklearn.preprocessing import LabelEncoder

# %%
model = Sequential([Dense(128, input_shape = (128,), activation = 'relu'),
                    Dense(64, activation = 'relu', kernel_initializer = 'he_uniform'),
                    Dense(64, activation = 'relu',  kernel_initializer = 'he_uniform'),
                    Dense(32, activation = 'relu',  kernel_initializer = 'he_uniform'),
                    Dense(32, activation = 'relu',  kernel_initializer = 'he_uniform'),
                    Dense(5, activation = 'softmax')])

model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam' ,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 32,229
# Trainable params: 32,229
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = pickle.loads(open('Trined_Embeddings', "rb").read())

le = LabelEncoder()
labels = le.fit_transform(data["names"])

# %%
embeddings = data["embeddings"]
embeddings = np.array(embeddings)
h = model.fit(embeddings, labels, epochs = 50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.5237 - accuracy: 1.0000
# Epoch 2/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4538 - accuracy: 1.0000
# Epoch 3/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3721 - accuracy: 1.0000
# Epoch 4/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2829 - accuracy: 1.0000
# Epoch 5/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1898 - accuracy: 1.0000
# Epoch 6/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0868 - accuracy: 1.0000
# Epoch 7/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9774 - accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8616 - accuracy: 1.0000
# Epoch 9/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7414 - accuracy: 1.0000
# Epoch 10/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6209 - accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5036 - accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3917 - accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2924 - accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2092 - accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1428 - accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0931 - accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0691e-04 - accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6745e-04 - accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 15ms/step - loss: 3.1603e-04 - accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 14ms/step - loss: 2.1851e-04 - accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.5450e-04 - accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1172e-04 - accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 11ms/step - loss: 8.2553e-05 - accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 11ms/step - loss: 6.2289e-05 - accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7912e-05 - accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7550e-05 - accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 15ms/step - loss: 2.9958e-05 - accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 15ms/step - loss: 2.4346e-05 - accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0073e-05 - accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6799e-05 - accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4268e-05 - accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2269e-05 - accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0674e-05 - accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 13ms/step - loss: 9.4175e-06 - accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 10ms/step - loss: 8.4088e-06 - accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 12ms/step - loss: 7.5652e-06 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 11ms/step - loss: 6.8774e-06 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 12ms/step - loss: 6.2814e-06 - accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 12ms/step - loss: 5.7770e-06 - accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 13ms/step - loss: 5.3644e-06 - accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0251e-06 - accuracy: 1.0000

# %%
# write the actual face recognition model to disk
model.save('recognizer.h5')
# write the label encoder to disk
f = open("label_Encoder", "wb")
f.write(pickle.dumps(le))
f.close()

# %%
from keras.models import load_model

# %%
recognizer = load_model('recognizer.h5')

le = pickle.loads(open("label_Encoder", "rb").read())
le.classes_[0] = 'Tandrima'

# %%
def image_recognize(image):
    image = cv2.resize(image, (640, 480))
    (h, w) = image.shape[:2]
    imageBlob = cv2.dnn.blobFromImage( cv2.resize(image, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0), 
                                      swapRB=False, crop=False)
    
    detector.setInput(imageBlob)
    detections = detector.forward()
    
    for i in range(0, detections.shape[2]):
    
        # extract the confidence (i.e., probability) associated with the prediction
        confidence = detections[0, 0, i, 2]

        # filter out weak detections
        if confidence > 0.85:
            # compute the (x, y)-coordinates of the bounding box for the face

            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # extract the face ROI

            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]

            # ensure the face width and height are sufficiently large
    
            if fW < 30 or fH < 30:
                continue
                
            faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255, (96, 96), (0, 0, 0), swapRB=True, crop=False)
            embedder.setInput(faceBlob)
            vec = embedder.forward()

            # perform classification to recognize the face
            
            preds = recognizer.predict(vec)[0]
            j = np.argmax(preds)

            proba = preds[j]
            name = le.classes_[j]
            if proba >= 0.40:
                text = name

                cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)
                cv2.putText(image, text, (startX, startY), cv2.FONT_HERSHEY_DUPLEX, 1.2, (0, 255, 0), 2)

    return np.array(image)

# %%
imagePaths = []
main_dir = 'drive/MyDrive/Faceit/Test_data'
main_dir_list = os.listdir(main_dir)
for image in main_dir_list:
    imagePath = os.path.sep.join([main_dir, image])
    imagePaths.append(imagePath)

# %%
import matplotlib.pyplot as plt
c = 1
fig = plt.figure(figsize = (30,18)) 
for i in imagePaths:
    image = cv2.imread(i)
    image= image_recognize(image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    fig.add_subplot(3,4,c)
    plt.imshow(image)
    plt.xticks([])
    plt.yticks([])
    c += 1
plt.show()
# Out:
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# using a webcam
cam = cv2.VideoCapture(1)
#out = cv2.VideoWriter('Face-Mask.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (640,480))
cam.set(3,640)
cam.set(4,480)
cam.set(10,130)

while True:
    success, image = cam.read()
    if success == True:
        image_recognize(image)
        cv2.imshow("Result", image)
        #out.write(image)
        if cv2.waitKey(1) & 0xFF == ord('a'):
            break
cam.release()
#out.release()
cv2.destroyAllWindows()
